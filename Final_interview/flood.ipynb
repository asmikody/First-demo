# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
from scipy.stats import zscore

# %%
df = pd.read_csv(r"C:\Users\BAPS\Downloads\Regression_MODELS\Flood_Prediction_NCR_Philippines.csv")

# %%
df.head()
# Out:
#          Date     Location  Rainfall_mm  WaterLevel_m  SoilMoisture_pct  \
# 0  2016-01-01  Quezon City         12.0           0.5              15.3
# 1  2016-01-01     Marikina         10.6           1.8              23.2
# 2  2016-01-01       Manila          5.7           0.5              15.6
# 3  2016-01-01        Pasig          3.7           0.5               5.0
# 4  2016-01-02  Quezon City          3.4           0.5              13.3
#
#    Elevation_m  FloodOccurrence
# 0           43                0
# 1           15                0
# 2            5                0
# 3            5                0
# 4           43                0

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# Rainfall_mm         0
# WaterLevel_m        0
# SoilMoisture_pct    0
# Elevation_m         0
# FloodOccurrence     0
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7308 non-null   datetime64[ns]
#  1   Location          7308 non-null   object
#  2   Rainfall_mm       7308 non-null   float64
#  3   WaterLevel_m      7308 non-null   float64
#  4   SoilMoisture_pct  7308 non-null   float64
#  5   Elevation_m       7308 non-null   int64
#  6   FloodOccurrence   7308 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 399.8+ KB

# %%
df.head()
# Out:
#         Date     Location  Rainfall_mm  WaterLevel_m  SoilMoisture_pct  \
# 0 2016-01-01  Quezon City         12.0           0.5              15.3
# 1 2016-01-01     Marikina         10.6           1.8              23.2
# 2 2016-01-01       Manila          5.7           0.5              15.6
# 3 2016-01-01        Pasig          3.7           0.5               5.0
# 4 2016-01-02  Quezon City          3.4           0.5              13.3
#
#    Elevation_m  FloodOccurrence  Year
# 0           43                0  2016
# 1           15                0  2016
# 2            5                0  2016
# 3            5                0  2016
# 4           43                0  2016

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year

# %%
dataset = pd.get_dummies(df, columns=['Location'],dtype=int,dr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dataset = pd.get_dummies(df, columns=['Location']).astype(int)
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:179, in astype_array(values, dtype, copy)
#     175     return values
#     177 if not isinstance(values, np.ndarray):
#     178     # i.e. ExtensionArray
# --> 179     values = values.astype(dtype, copy=copy)
#     181 else:
#     182     values = _astype_nansafe(values, dtype, copy=copy)
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:741, in DatetimeArray.astype(self, dtype, copy)
#     739 elif isinstance(dtype, PeriodDtype):
#     740     return self.to_period(freq=dtype.freq)
# --> 741 return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#
# File c:\Users\BAPS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimelike.py:505, in DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     503 values = self.asi8
#     504 if dtype != np.int64:
# --> 505     raise TypeError(
#     506         f"Converting from {self.dtype} to {dtype} is not supported. "
#     507         "Do obj.astype('int64').astype(dtype) instead"
#     508     )
#     510 if copy:
#     511     values = values.copy()
#
# TypeError: Converting from datetime64[ns] to int32 is not supported. Do obj.astype('int64').astype(dtype) instead

# %%
dataset.head()
# Out:
#         Date  Rainfall_mm  WaterLevel_m  SoilMoisture_pct  Elevation_m  \
# 0 2016-01-01         12.0           0.5              15.3           43
# 1 2016-01-01         10.6           1.8              23.2           15
# 2 2016-01-01          5.7           0.5              15.6            5
# 3 2016-01-01          3.7           0.5               5.0            5
# 4 2016-01-02          3.4           0.5              13.3           43
#
#    FloodOccurrence  Year  Location_Manila  Location_Marikina  Location_Pasig  \
# 0                0  2016            False              False           False
# 1                0  2016            False               True           False
# 2                0  2016             True              False           False
# 3                0  2016            False              False            True
# 4                0  2016            False              False           False
#
#    Location_Quezon City
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                  True
